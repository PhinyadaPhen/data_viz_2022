# %% [markdown]
# <a href="https://colab.research.google.com/github/PhinyadaPhen/data_viz_2022/blob/main/CRM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive #เชื่อมต่อ colab เข้ากับไดร์ฟในข้อมูล
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os #จัดการหาไฟล์ที่อยู่ในไดร์ฟ

# %%
path = '/content/drive/My Drive/DWDM2021_DATA'

# %%
data_crm = os.path.join(path,'ex.csv') #เอาพาร์ทที่อยู่ในไฟล์มาเชื่อมกับColab
print(data_crm)
# Out:
# /content/drive/My Drive/DWDM2021_DATA/ex.csv

# %%
crm = pd.read_csv(data_crm)
crm
# Out:
#          _id รูปแบบการเดินทาง              วัตถุประสงค์ สาธารณะ/ส่วนบุคคล  \
# 0          1           ทางถนน  การเดินทางระหว่างจังหวัด           สาธารณะ
# 1          2           ทางถนน  การเดินทางระหว่างจังหวัด         ส่วนบุคคล
# 2          3           ทางถนน  การเดินทางระหว่างจังหวัด         ส่วนบุคคล
# 3          4           ทางถนน  การเดินทางระหว่างจังหวัด         ส่วนบุคคล
# 4          5           ทางถนน  การเดินทางระหว่างจังหวัด         ส่วนบุคคล
# ...      ...              ...                       ...               ...
# 32477  32478         ทางอากาศ   การเดินทางระหว่างประเทศ           สาธารณะ
# 32478  32479         ทางอากาศ   การเดินทางระหว่างประเทศ           สาธารณะ
# 32479  32480         ทางอากาศ   การเดินทางระหว่างประเทศ           สาธารณะ
# 32480  32481         ทางอากาศ   การเดินทางระหว่างประเทศ           สาธารณะ
# 32481  32482         ทางอากาศ   การเดินทางระหว่างประเทศ           สาธารณะ
#
#       หน่วยงาน                         ยานพาหนะ/ท่า               วันที่  \
# ...

# %%
data1all_alldb = crm[crm['รูปแบบการเดินทาง']=='ทางถนน']
   # ชี้ข้อมูลคอลัมน์ที่ต้องการ
data1all_alldb
# Out:
#          _id รูปแบบการเดินทาง                    วัตถุประสงค์  \
# 0          1           ทางถนน        การเดินทางระหว่างจังหวัด
# 1          2           ทางถนน        การเดินทางระหว่างจังหวัด
# 2          3           ทางถนน        การเดินทางระหว่างจังหวัด
# 3          4           ทางถนน        การเดินทางระหว่างจังหวัด
# 4          5           ทางถนน        การเดินทางระหว่างจังหวัด
# ...      ...              ...                             ...
# 32448  32449           ทางถนน  การเดินทางภายในจังหวัด/กรุงเทพ
# 32449  32450           ทางถนน  การเดินทางภายในจังหวัด/กรุงเทพ
# 32450  32451           ทางถนน  การเดินทางภายในจังหวัด/กรุงเทพ
# 32468  32469           ทางถนน         การเดินทางระหว่างประเทศ
# 32469  32470           ทางถนน         การเดินทางระหว่างประเทศ
#
#       สาธารณะ/ส่วนบุคคล หน่วยงาน                     ยานพาหนะ/ท่า  \
# 0               สาธารณะ     บขส.               รถ ขบส. และ รถร่วม
# 1             ส่วนบุคคล      ทล.  รถยนต์เฉพาะ 4 ล้อ (10 จุดสำรวจ)
# ...

# %%
crm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32482 entries, 0 to 32481
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   _id                32482 non-null  int64
#  1   รูปแบบการเดินทาง   32482 non-null  object
#  2   วัตถุประสงค์       32482 non-null  object
#  3   สาธารณะ/ส่วนบุคคล  32482 non-null  object
#  4   หน่วยงาน           32482 non-null  object
#  5   ยานพาหนะ/ท่า       32482 non-null  object
#  6   วันที่             32482 non-null  object
#  7   หน่วย              32482 non-null  object
#  8   ปริมาณ             32482 non-null  float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 2.2+ MB

# %%
data1all_alldb.to_csv('data1all_alldb.csv', encoding='utf-8')

# %%
waaaa = crm[crm['รูปแบบการเดินทาง']=='ทางน้ำ']
   # ชี้ข้อมูลคอลัมน์ที่ต้องการ
waaaa
# Out:
#          _id รูปแบบการเดินทาง                    วัตถุประสงค์  \
# 7          8           ทางน้ำ  การเดินทางภายในจังหวัด/กรุงเทพ
# 8          9           ทางน้ำ  การเดินทางภายในจังหวัด/กรุงเทพ
# 9         10           ทางน้ำ  การเดินทางภายในจังหวัด/กรุงเทพ
# 34        35           ทางน้ำ  การเดินทางภายในจังหวัด/กรุงเทพ
# 35        36           ทางน้ำ  การเดินทางภายในจังหวัด/กรุงเทพ
# ...      ...              ...                             ...
# 32453  32454           ทางน้ำ  การเดินทางภายในจังหวัด/กรุงเทพ
# 32454  32455           ทางน้ำ  การเดินทางภายในจังหวัด/กรุงเทพ
# 32455  32456           ทางน้ำ  การเดินทางภายในจังหวัด/กรุงเทพ
# 32472  32473           ทางน้ำ         การเดินทางระหว่างประเทศ
# 32473  32474           ทางน้ำ         การเดินทางระหว่างประเทศ
#
#       สาธารณะ/ส่วนบุคคล หน่วยงาน                    ยานพาหนะ/ท่า  \
# 7               สาธารณะ      จท.               เรือด่วนเจ้าพระยา
# 8               สาธารณะ      จท.                  เรือคลองแสนแสบ
# ...

# %%
waaaa.to_csv('waaaa.csv', encoding='utf-8')

# %%
train = crm[crm['รูปแบบการเดินทาง']=='ทางราง']
   # ชี้ข้อมูลคอลัมน์ที่ต้องการ
train
# Out:
#          _id รูปแบบการเดินทาง                    วัตถุประสงค์  \
# 10        11           ทางราง        การเดินทางระหว่างจังหวัด
# 11        12           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 12        13           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 13        14           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 14        15           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# ...      ...              ...                             ...
# 32459  32460           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 32460  32461           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 32461  32462           ทางราง  การเดินทางภายในจังหวัด/กรุงเทพ
# 32470  32471           ทางราง         การเดินทางระหว่างประเทศ
# 32471  32472           ทางราง         การเดินทางระหว่างประเทศ
#
#       สาธารณะ/ส่วนบุคคล หน่วยงาน                     ยานพาหนะ/ท่า  \
# 10              สาธารณะ     รฟท.                             รถไฟ
# 11              สาธารณะ     รฟม.              รถไฟฟ้าสายสีน้ำเงิน
# ...

# %%
train.to_csv('train.csv', encoding='utf-8')

# %%
air = crm[crm['รูปแบบการเดินทาง']=='ทางอากาศ']
   # ชี้ข้อมูลคอลัมน์ที่ต้องการ
air
# Out:
#          _id รูปแบบการเดินทาง              วัตถุประสงค์ สาธารณะ/ส่วนบุคคล  \
# 15        16         ทางอากาศ  การเดินทางระหว่างจังหวัด           สาธารณะ
# 16        17         ทางอากาศ  การเดินทางระหว่างจังหวัด           สาธารณะ
# 17        18         ทางอากาศ  การเดินทางระหว่างจังหวัด           สาธารณะ
# 18        19         ทางอากาศ  การเดินทางระหว่างจังหวัด           สาธารณะ
# 19        20         ทางอากาศ   การเดินทางระหว่างประเทศ           สาธารณะ
# ...      ...              ...                       ...               ...
# 32477  32478         ทางอากาศ   การเดินทางระหว่างประเทศ           สาธารณะ
# 32478  32479         ทางอากาศ   การเดินทางระหว่างประเทศ           สาธารณะ
# 32479  32480         ทางอากาศ   การเดินทางระหว่างประเทศ           สาธารณะ
# 32480  32481         ทางอากาศ   การเดินทางระหว่างประเทศ           สาธารณะ
# 32481  32482         ทางอากาศ   การเดินทางระหว่างประเทศ           สาธารณะ
#
#       หน่วยงาน                         ยานพาหนะ/ท่า               วันที่  \
# ...

# %%
air.to_csv('air.csv', encoding='utf-8')

# %%
patternn = crm.groupby('ยานพาหนะ/ท่า').size().reset_index(name='จำนวน')
patternn
# Out:
#                            ยานพาหนะ/ท่า  จำนวน
# 0                   ท่าอากาศยานดอนเมือง    950
# 1       ท่าอากาศยานดอนเมือง ขาออกประเทศ    950
# 2      ท่าอากาศยานดอนเมือง ขาเข้าประเทศ    950
# 3                    ท่าอากาศยานภูมิภาค    950
# 4        ท่าอากาศยานภูมิภาค ขาออกประเทศ    950
# 5       ท่าอากาศยานภูมิภาค ขาเข้าประเทศ    950
# 6                       ท่าอากาศยานสมุย    274
# 7                 ท่าอากาศยานสุวรรณภูมิ    950
# 8     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ    950
# 9    ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    950
# 10                  ท่าอากาศยานอู่ตะเภา    274
# 11              ท่าอากาศอื่น ๆ ของ ทอท.    950
# 12  ท่าอากาศอื่น ๆ ของ ทอท. ขาออกประเทศ    950
# 13  ท่าอากาศอื่น ๆ ของ ทอท.ขาเข้าประเทศ    950
# 14        ท่าเรือด่านชายแดน ขาออกประเทศ    874
# 15       ท่าเรือด่านชายแดน ขาเข้าประเทศ    859
# 16                   รถ ขบส. และ รถร่วม    950
# 17                  รถ บขส. ขาออกประเทศ     85
# 18                 รถ บขส. ขาเข้าประเทศ     85
# ...

# %%
patternn1 = crm.groupby('รูปแบบการเดินทาง').size().reset_index(name='จำนวน')
patternn1
# Out:
#   รูปแบบการเดินทาง  จำนวน
# 0           ทางถนน   9470
# 1           ทางน้ำ   5861
# 2           ทางราง   5203
# 3         ทางอากาศ  11948
