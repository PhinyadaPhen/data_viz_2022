# %% [markdown]
# <a href="https://colab.research.google.com/github/PhinyadaPhen/data_viz_2022/blob/main/ProjectDashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # import ฟังก์ชัน pandas

# %%
from google.colab import drive # package เชื่อม google  drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # จัดการเกี่ยวกับไฟล์ต่างๆ ในโฟล์เดอร์

# %%
path = '/content/drive/My Drive/dataviz_2021_data' # ชี้ว่า data เราอยู่โฟล์เดอร์ไหน

# %%
data_file_path = os.path.join(path,'confirmed(1).csv') # เอาที่อยู่ของไฟล์เชื่อมกับที่อยู่ของไฟล์เรา โดยกำหนดชื่่อไฟล์ที่เราต้องการ
datacovid1 = pd.read_csv(data_file_path)
datacovid1
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# ...

# %%
data_file_path = os.path.join(path,'confirmed(2).csv') # เอาที่อยู่ของไฟล์เชื่อมกับที่อยู่ของไฟล์เรา โดยกำหนดชื่่อไฟล์ที่เราต้องการ
datacovid2 = pd.read_csv(data_file_path)
datacovid2
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %%
data_file_path = os.path.join(path,'confirmed(3).csv') # เอาที่อยู่ของไฟล์เชื่อมกับที่อยู่ของไฟล์เรา โดยกำหนดชื่่อไฟล์ที่เราต้องการ
datacovid3 = pd.read_csv(data_file_path)
datacovid3
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# ...

# %%
data_file_path = os.path.join(path,'confirmed(4).csv') # เอาที่อยู่ของไฟล์เชื่อมกับที่อยู่ของไฟล์เรา โดยกำหนดชื่่อไฟล์ที่เราต้องการ
datacovid4 = pd.read_csv(data_file_path)
datacovid4
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %%
datamix = pd.concat([datacovid1,datacovid2,datacovid3,datacovid4])
datamix
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# # จัดการค่า missing

# %%
datamix.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
datamix['province_of_onset'].mode() # หาค่าที่พบมากที่สุดของ province_of_onset โดยใช้ฐานนิยม
# Out:
# 0    กรุงเทพมหานคร
# dtype: object

# %%
datacc = datamix.fillna(value={'province_of_onset':'กรุงเทพมหานคร'}) # แทนค่า 'กรุงเทพมหานคร' แทนค่า missing
datacc
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %%
datacc.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
data_cv = datacc[['No.','announce_date','province_of_onset']]
data_cv
# Out:
#             No. announce_date province_of_onset
# 0             1     12/1/2020     กรุงเทพมหานคร
# 1             2     17/1/2020     กรุงเทพมหานคร
# 2             3     22/1/2020            นครปฐม
# 3             4     22/1/2020     กรุงเทพมหานคร
# 4             5     24/1/2020     กรุงเทพมหานคร
# ...         ...           ...               ...
# 433548  3303165     18/3/2022     กรุงเทพมหานคร
# 433549  3303166     18/3/2022     กรุงเทพมหานคร
# 433550  3303167     18/3/2022     กรุงเทพมหานคร
# 433551  3303168     18/3/2022     กรุงเทพมหานคร
# 433552  3303169     18/3/2022     กรุงเทพมหานคร
#
# [3325951 rows x 3 columns]

# %%
data_cv.isnull().any() 
# ไม่มีค่า missing แล้ว
# Out:
# No.                  False
# announce_date        False
# province_of_onset    False
# dtype: bool

# %%
# data_cv.shape # ดูขนาดข้อมูล แถว*คอลัมน์
# Out:
# (3325951, 3)

# %%
len(set(data_cv['province_of_onset']))    # ดูว่าข้อมูลใน province_of_onset มีกี่ค่า
# จะเห็นได้ว่ามี 105 ค่า แสดงว่าข้อมูลมีค่าผิดปกติ เนื่องจาก ประเทศไทยมี 77 จังหวัด
# Out:
# 437

# %%
set(data_cv['province_of_onset'])
# Out:
# {'\tประจวบคีรีขันธ์',
#  'USA',
#  '\xa0กาญจนบุรี',
#  '\xa0ชลบุรี',
#  '\xa0ตราด',
#  '\xa0นครปฐม',
#  '\xa0สมุทรสงคราม',
#  '\xa0สมุทรสาคร',
#  '\xa0อุทัยธานี',
#  'กทม',
#  'กทม.',
#  'กบินทร์บุรี',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร.',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กาฬสินธ์',
#  'กำเพงเพชร',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กำแพงเพชร\xa0',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขอนแก่่น',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'ขานุวรลักษณ์บุรี',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จ.สุราษฎร์ธานี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\t',
#  'ชลบุรี\xa0',
#  'ชลบุุรี',
#  'ชอนแก่น',
#  'ชัยนาถ',
# ...

# %%
data_cv['province_of_onset'].replace({'กทม.':'กรุงเทพมหานคร'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data_cv['province_of_onset'].replace({'กรุงเทพมหานคร.','กรุงเทพมหานคร. / พระนครศรีอยุธยา','กรุงเทพ','กรุงเทพฯ','กทม','กทม.','กรุงเทพมหานคร. / ศรีสะเกษ','คลองเตย','จ.กรุงเทพมหานคร','ดินแดง','บางกะปิ','บางนา','ภาษีเจริญ','ยานนาวา','ราชเทวี','ลาดกระบัง','ลาดพร้าว','สะพานสูง','ห้วยขวาง':'กรุงเทพมหานคร'}, inplace=True)
# Out:
#   File "<ipython-input-45-22f02e18cef7>", line 1
#     data_cv['province_of_onset'].replace({'กรุงเทพมหานคร.','กรุงเทพมหานคร. / พระนครศรีอยุธยา','กรุงเทพ','กรุงเทพฯ','กทม','กทม.','กรุงเทพมหานคร. / ศรีสะเกษ','คลองเตย','จ.กรุงเทพมหานคร','ดินแดง','บางกะปิ','บางนา','ภาษีเจริญ','ยานนาวา','ราชเทวี','ลาดกระบัง','ลาดพร้าว','สะพานสูง','ห้วยขวาง':'กรุงเทพมหานคร'}, inplace=True)
#                                                                                                                                                                                                                                                                                                ^
# SyntaxError: invalid syntax

# %%
data_cv['province_of_onset'].replace({'กรุงเทพมหานคร.','กรุงเทพมหานคร. / พระนครศรีอยุธยา','กรุงเทพ','กรุงเทพฯ','กทม','กทม.','กรุงเทพมหานคร. / ศรีสะเกษ','คลองเตย','จ.กรุงเทพมหานคร','ดินแดง','บางกะปิ','บางนา','ภาษีเจริญ','ยานนาวา','ราชเทวี','ลาดกระบัง','ลาดพร้าว','สะพานสูง','ห้วยขวาง':'กรุงเทพมหานคร',
                                      'นครนาชสีมา','นครราขสีมา','นครราชธานี','นครราชศรีมา','นครราชสสีมา','นครราชสีมา ลพบุรี','นครราชสีมา\xa0','นคราชสีมา':'นครราชสีมา',
                                      'นครศรธรรมราช','นครศรี','นครศรีธรมมราช','นครศรีธรมราช','นครศรีธรรมราข','นครศรีฯ','นครศรีีธรรมราช','นครศร๊ธรรมราช','นครศร๊ะรรมราช','นครสรีธรรมราช','นครสีธรรมราช','นครฯ','นครีศรีธรรมราช','นรศรีธรรมราช':'นครศรีธรรมราช',
                                      'นคนปฐม','\xa0นครปฐม','นคปฐม','นครนปฐม','นครปฐม','นครปฐม\xa0','นครปบม','นตรปฐม':'นครปฐม',
                                      'ไชโย','โพธิ์ทอง','อ่งทอง','อ่างทอง\xa0':'อ่างทอง',
                                      'นครยายก','นตรนายก':'นครนายก',
                                      'นครพนม\xa0':'นครพนม',
                                      'นครสรรค์','นครสวรรค','นครสวรรค์\xa0':'นครสวรรค์',
                                      'นราธิวาส\u200b','นราธฺวาส', 'นาราธิวาส':'นราธิวาส',
                                      'น่าน/ฉะเชิงเทรา':'น่าน',
                                      'ประจวนคีรีขันธ็','ประจวบ','ประจวบคิรีขันธ์','ประจวบคีรขันธ์','ประจวบคีรขัันธ์','ประจวบคีรีขัน','ประจวบคีรีขันธื','ประจวบคีรีขันธฺ','ประจวบคีรีขันธ์\xa0','ประจวบคีรีขันธ์์','ประจวบคีรีขัันธ์','ประจวบคีีรีขันธ์','ประจวบฯ':'ประจวบคีรีขันธ์',
                                      'นนทบุรี\xa0','นนทบุุรี', 'นนทุบรี','นนทุรี','นนมบุรี':'นนทบุรี',
                                      'ท้ายบ้าน', 'บางเพียง', 'สมถทรปราการ', 'สมุครปราการ', 'สมุท', 'สมุทปราการ', 'สมุทรปรากร', 'สมุทรปรากรร', 'สมุทรปรากา', 'สมุทรปราการ', 'สมุทรปราการ\xa0', 'สมุทราปราการ', 'สมุุทรปราการ', 'สุทรปราการ', 'สุมทรปราการ', 'สุมุทรปราการ', 'สุวรรณภูมิ' : 'สมุทรปราการ'}, inplace=True)
# Out:
#   File "<ipython-input-41-be0b46f9ae31>", line 1
#     data_cv['province_of_onset'].replace({'กรุงเทพมหานคร.','กรุงเทพมหานคร. / พระนครศรีอยุธยา','กรุงเทพ','กรุงเทพฯ','กทม','กทม.','กรุงเทพมหานคร. / ศรีสะเกษ','คลองเตย','จ.กรุงเทพมหานคร','ดินแดง','บางกะปิ','บางนา','ภาษีเจริญ','ยานนาวา','ราชเทวี','ลาดกระบัง','ลาดพร้าว','สะพานสูง','ห้วยขวาง':'กรุงเทพมหานคร',
#                                                                                                                                                                                                                                                                                                ^
# SyntaxError: invalid syntax
